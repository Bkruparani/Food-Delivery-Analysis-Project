# %%
import pandas as pd

# %%
df = pd.read_excel('/content/Excel Food Delivery Project.xlsx')

# %%
df
# Out:
#      Customer_id  Gender       Age       City Order_id           Order_date  \
# 0          C6687   OTHER     Adult  Islamabad   O10687  2023-01-09 00:00:00
# 1          C3733    MALE     Adult     Multan    O7733  2023-01-09 00:00:00
# 2          C5566   OTHER  Teenager  Islamabad    O9566  2023-01-09 00:00:00
# 3          C3775   OTHER     Adult     Multan    O7775  2023-01-09 00:00:00
# 4          C3210   OTHER  Teenager    Karachi    O7210  2023-01-09 00:00:00
# ...          ...     ...       ...        ...      ...                  ...
# 5991       C5821   OTHER     Adult   Peshawar    O9821            9/30/2024
# 5992       C5296   OTHER     Adult     Lahore    O9296            9/30/2024
# 5993       C3665  FEMALE     Adult  Islamabad    O7665            9/30/2024
# 5994       C5319  FEMALE     Adult     Lahore    O9319            9/30/2024
# 5995       C6222   OTHER     Adult     Multan   O10222            9/30/2024
#
# ...

# %%
df.head()
# Out:
#   Customer_id Gender       Age       City Order_id           Order_date  \
# 0       C6687  OTHER     Adult  Islamabad   O10687  2023-01-09 00:00:00
# 1       C3733   MALE     Adult     Multan    O7733  2023-01-09 00:00:00
# 2       C5566  OTHER  Teenager  Islamabad    O9566  2023-01-09 00:00:00
# 3       C3775  OTHER     Adult     Multan    O7775  2023-01-09 00:00:00
# 4       C3210  OTHER  Teenager    Karachi    O7210  2023-01-09 00:00:00
#
#   Restaurant_name Dish_Name     Category  Quantity   Price Payment_method  \
# 0             KFC     Pasta      Italian         3  101.29         Wallet
# 1     Burger King  Sandwich  Continental         4  172.76         Wallet
# 2          Subway     Pasta      Dessert         5  362.35           Cash
# 3     Burger King     Fries      Chinese         2  388.86           Cash
# 4     Burger King     Pasta    Fast Food         2  528.24           Cash
#
#    Order_frequency   Churned  Rating Delivery_status
# ...

# %%
df.tail()
# Out:
#      Customer_id  Gender    Age       City Order_id Order_date  \
# 5991       C5821   OTHER  Adult   Peshawar    O9821  9/30/2024
# 5992       C5296   OTHER  Adult     Lahore    O9296  9/30/2024
# 5993       C3665  FEMALE  Adult  Islamabad    O7665  9/30/2024
# 5994       C5319  FEMALE  Adult     Lahore    O9319  9/30/2024
# 5995       C6222   OTHER  Adult     Multan   O10222  9/30/2024
#
#      Restaurant_name Dish_Name     Category  Quantity    Price Payment_method  \
# 5991       Pizza Hut     Fries      Dessert         2   431.27         Wallet
# 5992       Pizza Hut     Fries    Fast Food         4   588.11           Cash
# 5993       Pizza Hut     Pasta    Fast Food         2  1118.14           Card
# 5994       Pizza Hut     Pasta  Continental         2  1298.64           Cash
# 5995       Pizza Hut  Sandwich  Continental         2  1368.66           Cash
#
#       Order_frequency   Churned  Rating Delivery_status
# 5991               11    Active       5       Cancelled
# ...

# %%
df.head(3)
# Out:
#   Customer_id Gender       Age       City Order_id           Order_date  \
# 0       C6687  OTHER     Adult  Islamabad   O10687  2023-01-09 00:00:00
# 1       C3733   MALE     Adult     Multan    O7733  2023-01-09 00:00:00
# 2       C5566  OTHER  Teenager  Islamabad    O9566  2023-01-09 00:00:00
#
#   Restaurant_name Dish_Name     Category  Quantity   Price Payment_method  \
# 0             KFC     Pasta      Italian         3  101.29         Wallet
# 1     Burger King  Sandwich  Continental         4  172.76         Wallet
# 2          Subway     Pasta      Dessert         5  362.35           Cash
#
#    Order_frequency   Churned  Rating Delivery_status
# 0               28  Inactive       3       Delivered
# 1               23  Inactive       5       Delivered
# 2               23    Active       5         Delayed

# %%
df.tail(3)
# Out:
#      Customer_id  Gender    Age       City Order_id Order_date  \
# 5993       C3665  FEMALE  Adult  Islamabad    O7665  9/30/2024
# 5994       C5319  FEMALE  Adult     Lahore    O9319  9/30/2024
# 5995       C6222   OTHER  Adult     Multan   O10222  9/30/2024
#
#      Restaurant_name Dish_Name     Category  Quantity    Price Payment_method  \
# 5993       Pizza Hut     Pasta    Fast Food         2  1118.14           Card
# 5994       Pizza Hut     Pasta  Continental         2  1298.64           Cash
# 5995       Pizza Hut  Sandwich  Continental         2  1368.66           Cash
#
#       Order_frequency   Churned  Rating Delivery_status
# 5993               27    Active       3         Delayed
# 5994               37  Inactive       3       Delivered
# 5995               16  Inactive       3       Cancelled

# %%
df.shape
# Out:
# (5996, 16)

# %%
df.columns
# Out:
# Index(['Customer_id', 'Gender', 'Age', 'City', 'Order_id', 'Order_date',
#        'Restaurant_name', 'Dish_Name', 'Category', 'Quantity', 'Price',
#        'Payment_method', 'Order_frequency', 'Churned', 'Rating',
#        'Delivery_status'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Customer_id         object
# Gender              object
# Age                 object
# City                object
# Order_id            object
# Order_date          object
# Restaurant_name     object
# Dish_Name           object
# Category            object
# Quantity             int64
# Price              float64
# Payment_method      object
# Order_frequency      int64
# Churned             object
# Rating               int64
# Delivery_status     object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5996 entries, 0 to 5995
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Customer_id      5996 non-null   object
#  1   Gender           5996 non-null   object
#  2   Age              5996 non-null   object
#  3   City             5996 non-null   object
#  4   Order_id         5996 non-null   object
#  5   Order_date       5996 non-null   object
#  6   Restaurant_name  5996 non-null   object
#  7   Dish_Name        5996 non-null   object
#  8   Category         5996 non-null   object
#  9   Quantity         5996 non-null   int64
#  10  Price            5996 non-null   float64
#  11  Payment_method   5996 non-null   object
#  12  Order_frequency  5996 non-null   int64
#  13  Churned          5996 non-null   object
#  14  Rating           5996 non-null   int64
#  15  Delivery_status  5996 non-null   object
# dtypes: float64(1), int64(3), object(12)
# ...

# %%
df.describe()
# Out:
#           Quantity        Price  Order_frequency       Rating
# count  5996.000000  5996.000000      5996.000000  5996.000000
# mean      2.992161   800.330083        25.298699     2.998165
# std       1.414840   404.881014        14.355152     1.405635
# min       1.000000   100.300000         1.000000     1.000000
# 25%       2.000000   440.720000        13.000000     2.000000
# 50%       3.000000   805.680000        25.000000     3.000000
# 75%       4.000000  1149.737500        37.000000     4.000000
# max       5.000000  1499.950000        50.000000     5.000000

# %%
df.isnull().sum()
# Out:
# Customer_id        0
# Gender             0
# Age                0
# City               0
# Order_id           0
# Order_date         0
# Restaurant_name    0
# Dish_Name          0
# Category           0
# Quantity           0
# Price              0
# Payment_method     0
# Order_frequency    0
# Churned            0
# Rating             0
# Delivery_status    0
# dtype: int64

# %%
df.fillna(method='ffill', inplace=True)
# Out:
# /tmp/ipykernel_7208/3970806690.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill', inplace=True)

# %%
df.dropna(inplace=True)
df
# Out:
#      Customer_id  Gender       Age       City Order_id           Order_date  \
# 0          C6687   OTHER     Adult  Islamabad   O10687  2023-01-09 00:00:00
# 1          C3733    MALE     Adult     Multan    O7733  2023-01-09 00:00:00
# 2          C5566   OTHER  Teenager  Islamabad    O9566  2023-01-09 00:00:00
# 3          C3775   OTHER     Adult     Multan    O7775  2023-01-09 00:00:00
# 4          C3210   OTHER  Teenager    Karachi    O7210  2023-01-09 00:00:00
# ...          ...     ...       ...        ...      ...                  ...
# 5991       C5821   OTHER     Adult   Peshawar    O9821            9/30/2024
# 5992       C5296   OTHER     Adult     Lahore    O9296            9/30/2024
# 5993       C3665  FEMALE     Adult  Islamabad    O7665            9/30/2024
# 5994       C5319  FEMALE     Adult     Lahore    O9319            9/30/2024
# 5995       C6222   OTHER     Adult     Multan   O10222            9/30/2024
#
# ...

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#      Customer_id  Gender       Age       City Order_id           Order_date  \
# 0          C6687   OTHER     Adult  Islamabad   O10687  2023-01-09 00:00:00
# 1          C3733    MALE     Adult     Multan    O7733  2023-01-09 00:00:00
# 2          C5566   OTHER  Teenager  Islamabad    O9566  2023-01-09 00:00:00
# 3          C3775   OTHER     Adult     Multan    O7775  2023-01-09 00:00:00
# 4          C3210   OTHER  Teenager    Karachi    O7210  2023-01-09 00:00:00
# ...          ...     ...       ...        ...      ...                  ...
# 5991       C5821   OTHER     Adult   Peshawar    O9821            9/30/2024
# 5992       C5296   OTHER     Adult     Lahore    O9296            9/30/2024
# 5993       C3665  FEMALE     Adult  Islamabad    O7665            9/30/2024
# 5994       C5319  FEMALE     Adult     Lahore    O9319            9/30/2024
# 5995       C6222   OTHER     Adult     Multan   O10222            9/30/2024
#
# ...

# %%
df.columns = df.columns.str.lower().str.replace(" ", "_")
df
# Out:
#      customer_id  gender       age       city order_id           order_date  \
# 0          C6687   OTHER     Adult  Islamabad   O10687  2023-01-09 00:00:00
# 1          C3733    MALE     Adult     Multan    O7733  2023-01-09 00:00:00
# 2          C5566   OTHER  Teenager  Islamabad    O9566  2023-01-09 00:00:00
# 3          C3775   OTHER     Adult     Multan    O7775  2023-01-09 00:00:00
# 4          C3210   OTHER  Teenager    Karachi    O7210  2023-01-09 00:00:00
# ...          ...     ...       ...        ...      ...                  ...
# 5991       C5821   OTHER     Adult   Peshawar    O9821            9/30/2024
# 5992       C5296   OTHER     Adult     Lahore    O9296            9/30/2024
# 5993       C3665  FEMALE     Adult  Islamabad    O7665            9/30/2024
# 5994       C5319  FEMALE     Adult     Lahore    O9319            9/30/2024
# 5995       C6222   OTHER     Adult     Multan   O10222            9/30/2024
#
# ...

# %%
df['order_date'] = pd.to_datetime(df['order_date'])
df
# Out:
#      customer_id  gender       age       city order_id order_date  \
# 0          C6687   OTHER     Adult  Islamabad   O10687 2023-01-09
# 1          C3733    MALE     Adult     Multan    O7733 2023-01-09
# 2          C5566   OTHER  Teenager  Islamabad    O9566 2023-01-09
# 3          C3775   OTHER     Adult     Multan    O7775 2023-01-09
# 4          C3210   OTHER  Teenager    Karachi    O7210 2023-01-09
# ...          ...     ...       ...        ...      ...        ...
# 5991       C5821   OTHER     Adult   Peshawar    O9821 2024-09-30
# 5992       C5296   OTHER     Adult     Lahore    O9296 2024-09-30
# 5993       C3665  FEMALE     Adult  Islamabad    O7665 2024-09-30
# 5994       C5319  FEMALE     Adult     Lahore    O9319 2024-09-30
# 5995       C6222   OTHER     Adult     Multan   O10222 2024-09-30
#
#      restaurant_name dish_name     category  quantity    price payment_method  \
# 0                KFC     Pasta      Italian         3   101.29         Wallet
# ...

# %%
df = df[df['rating'] > 3]
df
# Out:
#      customer_id  gender       age       city order_id order_date  \
# 1          C3733    MALE     Adult     Multan    O7733 2023-01-09
# 2          C5566   OTHER  Teenager  Islamabad    O9566 2023-01-09
# 4          C3210   OTHER  Teenager    Karachi    O7210 2023-01-09
# 8          C1871    MALE     Adult     Multan    O5871 2023-01-10
# 13         C1888   OTHER     Adult     Multan    O5888 2023-01-10
# ...          ...     ...       ...        ...      ...        ...
# 5986       C2596  FEMALE  Teenager     Lahore    O6596 2023-09-30
# 5987       C4165    MALE    Senior    Karachi    O8165 2023-09-30
# 5988       C3987    MALE     Adult     Lahore    O7987 2023-09-30
# 5990       C2785    MALE    Senior    Karachi    O6785 2024-09-30
# 5991       C5821   OTHER     Adult   Peshawar    O9821 2024-09-30
#
#      restaurant_name dish_name     category  quantity    price payment_method  \
# 1        Burger King  Sandwich  Continental         4   172.76         Wallet
# ...

# %%
df.sort_values(by='delivery_status', inplace=True)
df
# Out:
#      customer_id  gender       age       city order_id order_date  \
# 5991       C5821   OTHER     Adult   Peshawar    O9821 2024-09-30
# 4205       C2552  FEMALE     Adult   Peshawar    O6552 2024-04-15
# 1851       C5135   OTHER  Teenager   Peshawar    O9135 2025-05-08
# 1854       C3964   OTHER  Teenager    Karachi    O7964 2025-05-08
# 1855       C6294   OTHER     Adult     Multan   O10294 2025-05-08
# ...          ...     ...       ...        ...      ...        ...
# 4277       C3916   OTHER  Teenager  Islamabad    O7916 2025-04-20
# 1836       C1765   OTHER    Senior   Peshawar    O5765 2025-05-06
# 4219       C4181  FEMALE     Adult     Multan    O8181 2024-04-16
# 4230       C5635    MALE    Senior  Islamabad    O9635 2024-04-17
# 1          C3733    MALE     Adult     Multan    O7733 2023-01-09
#
#      restaurant_name dish_name     category  quantity    price payment_method  \
# 5991       Pizza Hut     Fries      Dessert         2   431.27         Wallet
# ...

# %%
df.groupby('city')['delivery_status'].value_counts()
df
# Out:
#      customer_id  gender       age       city order_id order_date  \
# 5991       C5821   OTHER     Adult   Peshawar    O9821 2024-09-30
# 4205       C2552  FEMALE     Adult   Peshawar    O6552 2024-04-15
# 1851       C5135   OTHER  Teenager   Peshawar    O9135 2025-05-08
# 1854       C3964   OTHER  Teenager    Karachi    O7964 2025-05-08
# 1855       C6294   OTHER     Adult     Multan   O10294 2025-05-08
# ...          ...     ...       ...        ...      ...        ...
# 4277       C3916   OTHER  Teenager  Islamabad    O7916 2025-04-20
# 1836       C1765   OTHER    Senior   Peshawar    O5765 2025-05-06
# 4219       C4181  FEMALE     Adult     Multan    O8181 2024-04-16
# 4230       C5635    MALE    Senior  Islamabad    O9635 2024-04-17
# 1          C3733    MALE     Adult     Multan    O7733 2023-01-09
#
#      restaurant_name dish_name     category  quantity    price payment_method  \
# 5991       Pizza Hut     Fries      Dessert         2   431.27         Wallet
# ...

# %%
df['month'] = df['order_date'].dt.month
df
# Out:
#      customer_id  gender       age       city order_id order_date  \
# 5991       C5821   OTHER     Adult   Peshawar    O9821 2024-09-30
# 4205       C2552  FEMALE     Adult   Peshawar    O6552 2024-04-15
# 1851       C5135   OTHER  Teenager   Peshawar    O9135 2025-05-08
# 1854       C3964   OTHER  Teenager    Karachi    O7964 2025-05-08
# 1855       C6294   OTHER     Adult     Multan   O10294 2025-05-08
# ...          ...     ...       ...        ...      ...        ...
# 4277       C3916   OTHER  Teenager  Islamabad    O7916 2025-04-20
# 1836       C1765   OTHER    Senior   Peshawar    O5765 2025-05-06
# 4219       C4181  FEMALE     Adult     Multan    O8181 2024-04-16
# 4230       C5635    MALE    Senior  Islamabad    O9635 2024-04-17
# 1          C3733    MALE     Adult     Multan    O7733 2023-01-09
#
#      restaurant_name dish_name     category  quantity    price payment_method  \
# 5991       Pizza Hut     Fries      Dessert         2   431.27         Wallet
# ...

# %%
df = pd.get_dummies(df, columns=['city'])
df
# Out:
#      customer_id  gender       age order_id order_date restaurant_name  \
# 5991       C5821   OTHER     Adult    O9821 2024-09-30       Pizza Hut
# 4205       C2552  FEMALE     Adult    O6552 2024-04-15     Burger King
# 1851       C5135   OTHER  Teenager    O9135 2025-05-08          Subway
# 1854       C3964   OTHER  Teenager    O7964 2025-05-08       Pizza Hut
# 1855       C6294   OTHER     Adult   O10294 2025-05-08       Pizza Hut
# ...          ...     ...       ...      ...        ...             ...
# 4277       C3916   OTHER  Teenager    O7916 2025-04-20             KFC
# 1836       C1765   OTHER    Senior    O5765 2025-05-06          Subway
# 4219       C4181  FEMALE     Adult    O8181 2024-04-16          Subway
# 4230       C5635    MALE    Senior    O9635 2024-04-17       Pizza Hut
# 1          C3733    MALE     Adult    O7733 2023-01-09     Burger King
#
#      dish_name     category  quantity    price  ... order_frequency   churned  \
# ...

# %%
df.drop(['order_id'], axis=0, inplace=True, errors='ignore')
df
# Out:
#      customer_id  gender       age order_date restaurant_name dish_name  \
# 5991       C5821   OTHER     Adult 2024-09-30       Pizza Hut     Fries
# 4205       C2552  FEMALE     Adult 2024-04-15     Burger King     Pasta
# 1851       C5135   OTHER  Teenager 2025-05-08          Subway  Sandwich
# 1854       C3964   OTHER  Teenager 2025-05-08       Pizza Hut    Burger
# 1855       C6294   OTHER     Adult 2025-05-08       Pizza Hut    Burger
# ...          ...     ...       ...        ...             ...       ...
# 4277       C3916   OTHER  Teenager 2025-04-20             KFC     Pasta
# 1836       C1765   OTHER    Senior 2025-05-06          Subway  Sandwich
# 4219       C4181  FEMALE     Adult 2024-04-16          Subway     Fries
# 4230       C5635    MALE    Senior 2024-04-17       Pizza Hut     Fries
# 1          C3733    MALE     Adult 2023-01-09     Burger King  Sandwich
#
#          category  quantity    price payment_method  order_frequency  \
# ...

# %%
df.to_csv('/content/cleaned_data.csv', index=False)
df
# Out:
#      customer_id  gender       age order_date restaurant_name dish_name  \
# 5991       C5821   OTHER     Adult 2024-09-30       Pizza Hut     Fries
# 4205       C2552  FEMALE     Adult 2024-04-15     Burger King     Pasta
# 1851       C5135   OTHER  Teenager 2025-05-08          Subway  Sandwich
# 1854       C3964   OTHER  Teenager 2025-05-08       Pizza Hut    Burger
# 1855       C6294   OTHER     Adult 2025-05-08       Pizza Hut    Burger
# ...          ...     ...       ...        ...             ...       ...
# 4277       C3916   OTHER  Teenager 2025-04-20             KFC     Pasta
# 1836       C1765   OTHER    Senior 2025-05-06          Subway  Sandwich
# 4219       C4181  FEMALE     Adult 2024-04-16          Subway     Fries
# 4230       C5635    MALE    Senior 2024-04-17       Pizza Hut     Fries
# 1          C3733    MALE     Adult 2023-01-09     Burger King  Sandwich
#
#          category  quantity    price payment_method  order_frequency  \
# ...
