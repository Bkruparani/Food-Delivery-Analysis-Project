# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
df = pd.read_csv('/content/Excel Food Delivery Project (1).csv')
df.head()
# Out:
#   Customer_id Gender       Age       City Order_id  Order_date  \
# 0       C6687  OTHER     Adult  Islamabad   O10687  09-01-2023
# 1       C3733   MALE     Adult     Multan    O7733  09-01-2023
# 2       C5566  OTHER  Teenager  Islamabad    O9566  09-01-2023
# 3       C3775  OTHER     Adult     Multan    O7775  09-01-2023
# 4       C3210  OTHER  Teenager    Karachi    O7210  09-01-2023
#
#   Restaurant_name Dish_Name     Category  Quantity   Price Payment_method  \
# 0             KFC     Pasta      Italian         3  101.29         Wallet
# 1     Burger King  Sandwich  Continental         4  172.76         Wallet
# 2          Subway     Pasta      Dessert         5  362.35           Cash
# 3     Burger King     Fries      Chinese         2  388.86           Cash
# 4     Burger King     Pasta    Fast Food         2  528.24           Cash
#
#    Order_frequency   Churned  Rating Delivery_status
# 0               28  Inactive       3       Delivered
# ...

# %%
sns.countplot(x='Delivery_status', data=df)
plt.title("Count of Delivery Status")
plt.show()

# %%
pd.crosstab(df['Delivery_status'], df['Payment_method']).plot(kind='bar')

plt.title("Delivery Status vs Payment Method")
plt.xlabel("Delivery Status")
plt.ylabel("Count")
plt.xticks(rotation=0)
plt.show()

# %%
sns.stripplot(x='Delivery_status', y='Order_frequency', data=df, size=4, jitter=True)

plt.title("Delivery Status vs Delivery Time")
plt.show()

# %%
pd.crosstab(df['City'], df['Delivery_status']).plot(kind='bar')

plt.title("City vs Delivery Status")
plt.xlabel("City")
plt.ylabel("Count")
plt.xticks(rotation=45)
plt.show()

# %%
sns.pairplot(df)

# %%
pd.plotting.scatter_matrix(df)
# Out:
# array([[<Axes: xlabel='Quantity', ylabel='Quantity'>,
#         <Axes: xlabel='Price', ylabel='Quantity'>,
#         <Axes: xlabel='Order_frequency', ylabel='Quantity'>,
#         <Axes: xlabel='Rating', ylabel='Quantity'>],
#        [<Axes: xlabel='Quantity', ylabel='Price'>,
#         <Axes: xlabel='Price', ylabel='Price'>,
#         <Axes: xlabel='Order_frequency', ylabel='Price'>,
#         <Axes: xlabel='Rating', ylabel='Price'>],
#        [<Axes: xlabel='Quantity', ylabel='Order_frequency'>,
#         <Axes: xlabel='Price', ylabel='Order_frequency'>,
#         <Axes: xlabel='Order_frequency', ylabel='Order_frequency'>,
#         <Axes: xlabel='Rating', ylabel='Order_frequency'>],
#        [<Axes: xlabel='Quantity', ylabel='Rating'>,
#         <Axes: xlabel='Price', ylabel='Rating'>,
#         <Axes: xlabel='Order_frequency', ylabel='Rating'>,
#         <Axes: xlabel='Rating', ylabel='Rating'>]], dtype=object)

# %%
sns.pairplot(df,hue='Gender')
